# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
test=pd.read_csv("D:\\titanic_data\\test.csv")
train=pd.read_csv("D:\\titanic_data\\train.csv")
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#statistical info

train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#datatype info

train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.countplot(train['Survived'])
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(train['Pclass'])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
mean_age=train['Age'].mean()
print(mean_age)
# Out:
# 29.69911764705882

# %%
median=train['Age'].median
print(median)
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64>

# %%
mode=train['Age'].mode
print(mode)
# Out:
# <bound method Series.mode of 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64>

# %%
std_age=train['Age'].std()
print(std_age)
# Out:
# 14.526497332334044

# %%
mean_age=train['Fare'].mean()
print(mean_age)
# Out:
# 32.2042079685746

# %%
train.groupby('Fare').mean()
# Out:
#           PassengerId  Survived    Pclass        Age  SibSp     Parch
# Fare
# 0.0000         516.40  0.066667  1.933333  35.142857   0.00  0.000000
# 4.0125         379.00  0.000000  3.000000  20.000000   0.00  0.000000
# 5.0000         873.00  0.000000  1.000000  33.000000   0.00  0.000000
# 6.2375         327.00  0.000000  3.000000  61.000000   0.00  0.000000
# 6.4375         844.00  0.000000  3.000000  34.500000   0.00  0.000000
# ...               ...       ...       ...        ...    ...       ...
# 227.5250       589.25  0.750000  1.000000  32.666667   0.25  0.000000
# 247.5208       209.50  0.500000  1.000000  37.000000   0.00  1.000000
# 262.3750       527.50  1.000000  1.000000  19.500000   2.00  2.000000
# 263.0000       224.50  0.500000  1.000000  32.500000   2.50  2.500000
# 512.3292       559.00  1.000000  1.000000  35.333333   0.00  0.333333
#
# [248 rows x 6 columns]

# %%
train.groupby('Fare').median()
# Out:
#           PassengerId  Survived  Pclass   Age  SibSp  Parch
# Fare
# 0.0000          482.0       0.0     2.0  38.0    0.0    0.0
# 4.0125          379.0       0.0     3.0  20.0    0.0    0.0
# 5.0000          873.0       0.0     1.0  33.0    0.0    0.0
# 6.2375          327.0       0.0     3.0  61.0    0.0    0.0
# 6.4375          844.0       0.0     3.0  34.5    0.0    0.0
# ...               ...       ...     ...   ...    ...    ...
# 227.5250        629.5       1.0     1.0  38.0    0.0    0.0
# 247.5208        209.5       0.5     1.0  37.0    0.0    1.0
# 262.3750        527.5       1.0     1.0  19.5    2.0    2.0
# 263.0000        215.5       0.5     1.0  23.5    3.0    2.0
# 512.3292        680.0       1.0     1.0  35.0    0.0    0.0
#
# [248 rows x 6 columns]

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
mean_age=test['Age'].mean()
print(mean_age)
# Out:
# 30.272590361445783

# %%
median=test['Age'].median
print(median)
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64>

# %%
mode=test['Age'].mode
print(mode)
# Out:
# <bound method Series.mode of 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64>

# %%
test.groupby('Fare').mean()
# Out:
#           PassengerId  Pclass   Age  SibSp  Parch
# Fare
# 0.0000         1211.0     1.0  49.0    0.0    0.0
# 3.1708          913.0     3.0   9.0    0.0    1.0
# 6.4375         1016.5     3.0   NaN    0.5    0.0
# 6.4958         1124.0     3.0  21.0    1.0    0.0
# 6.9500         1183.0     3.0  30.0    0.0    0.0
# ...               ...     ...   ...    ...    ...
# 227.5250       1094.0     1.0  47.0    1.0    0.0
# 247.5208       1076.0     1.0  27.0    1.0    1.0
# 262.3750       1024.8     1.0  40.6    0.8    1.6
# 263.0000        953.0     1.0  44.0    2.0    3.0
# 512.3292       1235.0     1.0  58.0    0.0    1.0
#
# [169 rows x 5 columns]

# %%
test.groupby('Fare').median()
# Out:
#           PassengerId  Pclass   Age  SibSp  Parch
# Fare
# 0.0000         1211.0     1.0  49.0    0.0    0.0
# 3.1708          913.0     3.0   9.0    0.0    1.0
# 6.4375         1016.5     3.0   NaN    0.5    0.0
# 6.4958         1124.0     3.0  21.0    1.0    0.0
# 6.9500         1183.0     3.0  30.0    0.0    0.0
# ...               ...     ...   ...    ...    ...
# 227.5250       1094.0     1.0  47.0    1.0    0.0
# 247.5208       1076.0     1.0  27.0    1.0    1.0
# 262.3750        956.0     1.0  45.0    1.0    2.0
# 263.0000        953.0     1.0  44.0    2.0    3.0
# 512.3292       1235.0     1.0  58.0    0.0    1.0
#
# [169 rows x 5 columns]
